# %% [markdown]
# <div style="background-color:	#216375 ; text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px">
# <h1 style="color:black"> Autonomous Systems: Portfolio 1 </h1>
# <b style="color:white"> Jort Akershoek, Julia Boschman, Daan Eising, Rogier Gernaat</b>
#     </div>
#
# <a name='start'></a>

# %% [markdown]
# ## Table of contents
#
# 1. [H1: Inleiding](#1.0)
#     - [&sect;1.1: Imports](#1.1)
# 2. [H2: Use Case](#2.0)
#     - [&sect;2.1: Kiezen van Use Case](#2.1)
#     - [&sect;2.2: Probleemdefinitie en Doelstelling](#2.2)
# 3. [H3: Ontwerp van de Regelset](#3.0)
# 4. [H4: Implementatie in Python](#4.0)
#     - [&sect;4.1: Systeemontwikkeling](#4.1)
#     - [&sect;4.2: Documentatie en Retroduceerbaarheid](#4.2)
# 5. [H5: Validatie en Vergelijking](#5.0)
#     - [&sect;5.1: Testen en Evaluatie](#5.1)
#     - [&sect;5.2: Vergelijking met Alternatieven](#5.2)
#     - [&sect;5.3: Visualisatie](#5.3)
# 6. [H6: Rapport](#6.0)
#     - [&sect;6.1: Probleemstelling](#6.1)
#     - [&sect;6.2: Methodologie](#6.2)
#     - [&sect;6.3: Resultaten](#6.3)
#     - [&sect;6.4: Reflectie](#6.4)
# 7. [H7: Literatuurlijst](#7.0)
# 8. [H8: Beoordelingscriteria](#8.0)

# %% [markdown]
# [Back to the top](#start)
# <a name='1.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H1: Inleiding</strong></h2>
# </div>

# %% [markdown]
# <a name='1.1'></a>
# <h3>&sect;1.1: Imports</h3>

# %%
import time
import main
import numpy as np
import matplotlib.pyplot as plt
from pettingzoo.classic import connect_four_v3
from IPython.display import display, clear_output

from main import env, convert_observation, rule_based_action, render_board, get_human_action, check_win
from main_verbeterd import render_board, convert_observation, ai_action_minimax, env

import random
from collections import defaultdict

# %%
# pip install pygame
# pip install pettingzoo

# %% [markdown]
# [Back to the top](#start)
# <a name='2.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H2: Use Case</strong></h2>
# </div>

# %% [markdown]
# - [X] Kies een omgeving van pettingzoo of Gymnasium Documentation (niet een omgeving die in de zelfstudie al gebruikt wordt).

# %% [markdown]
# <a name='2.1'></a>
# <h3>&sect;2.1: Kiezen van Use Case</h3>

# %% [markdown]
# Voor de opdracht van Autonomous Systems hebben wij gekeken naar de mogelijk opties die pettingzoo.com te bieden heeft. Er was één use case die ons allemaal aansprak en dat was de [Vier op een Rij](https://pettingzoo.farama.org/environments/classic/connect_four/) use case. Het leek ons een leuke maar ook lastige uitdaging. De hele groep is bekend met het spel en vinden het ook leuk om te doen. Dat is dan ook de voornaamste reden dat wij voor deze use case hebben gekozen.

# %% [markdown]
# - [X] Beschrijf helder welk probleem je wilt oplossen en waarom een rule-based benadering geschikt is.
# - [X] Analyseer het probleem: waarom is een rule-based systeem hier effectief en wat zijn de voordelen ten opzichte van alternatieve methoden zoals machine learning?

# %% [markdown]
# <a name='2.2'></a>
# <h3>&sect;2.2: Probleemdefinitie en Doelstelling</h3>

# %% [markdown]
# Connect Four is een strategisch spel voor twee spelers waarin de spelers om de beurt een schijfje (beide een eigen kleur) in een van de zeven kolommen laten vallen. Het doel is om als eerste vier de zelfde kleur schijven op een rij te krijgen (horizontaal, verticaal of diagonaal).
#
# Voor deze opdracht willen we een rule-based agent ontwikkelen die effectief tegen een menselijke tegenstander kan spelen. De uitdaging is om een set regels te definiëren die de agent in staat stelt om strategische zetten te maken en te reageren op acties van de tegenstander.
#
# De belangrijkste problemen die we willen aanpakken zijn:
# - ***Bepalen van de beste zet***: Hoe kan de agent op basis van regels een sterke zet kiezen?
# - ***Voorkomen van verlies***: Hoe kan de agent verlies vermijden door tegen de strategie van de tegenstander in te spelen?
# - ***Balans tussen aanvallen en verdedigen***: Hoe kan de agent slim kiezen tussen het opbouwen van een eigen winnende combinatie en het blokkeren van de tegenstander?
#
# Een rule-based systeem is hier een geschikte aanpak om de volgende redenen:
# - ***Transparantie en begrijpelijkheid***: In tegenstelling tot machine learning-modellen zijn rule-based systemen goed te begrijpen en uitlegbaar. We kunnen precies zien welke regels de agent volgt en waarom een bepaalde zet wordt gemaakt.
# - ***Snelheid en efficiëntie***: Een rule-based agent kan snelle beslissingen nemen zonder dat er complexe berekeningen of trainingstijd nodig is. Dit is handig voor real-time spelinteracties.
# - ***Duidelijke strategieën en patronen***: Veel succesvolle Connect Four-strategieën kunnen worden vertaald naar regels, zoals het blokkeren van een tegenstander met drie op een rij of het benutten van een vrije kolom voor een winnende zet.
# - ***Minder rekenkracht nodig***: In vergelijking met machine learning-modellen zoals deep reinforcement learning, vereist een rule-based systeem enn stuk minder rekenkracht en geheugen.
#
# Een alternatieve aanpak zoals machine learning (bijv. een reinforcement learning agent) zou mogelijk sterker kunnen zijn, maar heeft een lange trainingsperiode nodig en vereist een grote hoeveelheid data. Voor deze opdracht is een rule-based aanpak dus een logische keuze.

# %% [markdown]
# [Back to the top](#start)
# <a name='3.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H3: Vier op een Rij</strong></h2>
# </div>

# %% [markdown]
# Eerst geven we een korte weergave van de Vier op een Rij van de pettingzoo.com module. Het spel wordt door gespeeld tot een van de twee kleuren vier fiches naast elkaar heeft. Vier op een rij dus. De code is afkomstig van [deze](https://pettingzoo.farama.org/environments/classic/connect_four/) pettingzoo.com pagina.

# %%
env = connect_four_v3.env(render_mode="rgb_array")
env.reset(seed=42)

frames = []

for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()

    if termination or truncation:
        action = None
    else:
        mask = observation["action_mask"]
        action = env.action_space(agent).sample(mask)

    env.step(action)

    frame = env.render()
    frames.append(frame)

    plt.imshow(frame)
    plt.axis("off")
    clear_output(wait=True)
    display(plt.gcf())
    time.sleep(0.5)

env.close()

# %% [markdown]
# [Back to the top](#start)
# <a name='3.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H4: Ontwerp van de Regelstel</strong></h2>
# </div>

# %% [markdown]
# - [X] Definieer een uitgebreide set van regels die de beslissingen binnen het systeem sturen.
# - [X] Zorg dat de regels logisch en niet tegenstrijdig zijn.
# - [X] Licht toe hoe regels elkaar prioriteren of combineren indien meerdere regels van toepassing zijn.

# %% [markdown]
# Om te beginnen met het opstellen van regels voor een spel, moet er gekeken worden naar verschillende soorten regels. Er zijn hier ook verschillende lagen in, omdat er vaak meerdere mogelijke opties zijn, maar sommige zetten een hogere prioriteit hebben dan de andere. Zo is de zet met de hoogste prioriteit een winnende zet plaatsen. Deze heeft voorrang op een regel als "Het blokkeren van de vier op een rij van de tegenstander". Met de winnende zet is het spel namelijk afgelopen en heb je ook nog eens gewonnen. Hieronder worden de regels verdeeld onder vier soorten prioriteit van hoog naar middelhoog naar laag. Als er meerdere regels van toepassing zijn, moet de agent ze in een logische volgorde verwerken. Hieronder staan de regels in volgorde van belangrijkheid:
#
# ### Prioriteiten en Strategische Regels
#
# *Win- en Blokkeerregels (hoogste prioriteit)*
# - Regel 1: Als de agent een zet kan doen waarmee hij direct vier op een rij krijgt, doe deze zet.
# - Regel 2: Als de tegenstander een zet kan doen waarmee hij direct vier op een rij krijgt, blokkeer die zet.
#
# *Aanvalsstrategieën (middelhoge prioriteit)*
# - Regel 3: Speel in een kolom waar je later een winnende zet kunt forceren.
# - Regel 4: Probeer een dubbele dreiging te creëren (twee mogelijke win-situaties tegelijk).
#
# *Verdedigingsstrategieën (middelhoge prioriteit)*
# - Regel 5: Blokkeer tegenstander als hij drie op een rij heeft met een open einde.
# - Regel 6: Geef de voorkeur aan het spelen in de middelste kolommen boven de buitenste.
#
# *Positionele Voorkeuren (lage prioriteit)*
# - Regel 7: Vermijd zetten die de tegenstander een voordeel geven (bijv. een valstrik zetten waarin hij gegarandeerd wint).
# - Regel 8: Kies een willekeurige geldige zet als laatste optie.

# %% [markdown]
# [Back to the top](#start)
# <a name='4.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H5: Implementatie in Python</strong></h2>
# </div>

# %% [markdown]
# - [X] Implementeer je rule-based systeem in Python. Zorg ervoor dat je code modulair en overzichtelijk is.
# - [X] Implementeer een baseline.
# - [ ] Creëer een duidelijke mappenstructuur, een README-bestand en een requirements.txt waarin de gebruikte libraries staan vermeld.

# %% [markdown]
# <a name='4.1'></a>
# <h3>&sect;4.1: Systeemontwikkeling</h3>

# %% [markdown]
# <a name='5.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>Self testing</strong></h2>
# </div>

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>(Prototype Rogier) Aanpak:</strong> </div>
# Wij gaan dit stuk in drie delen opdelen. In het eerste deel testen we het spel zelf door het een groot aantal keren te laten spelen. Hierbij observeren we welke beslissingen het systeem neemt op basis van de opgestelde regels. We documenteren nauwkeurig onze bevindingen, waarbij we aangeven waar we mogelijke valkuilen constateren en of er duidelijke patronen of andere interessante gedragingen naar voren komen in de besluitvorming van het systeem.
#
# In het tweede deel gaan we dieper in op de rules zelf. Hierbij simuleren we een reeks games waarin speler 1 willekeurige zetten doet, terwijl we de beslissingen van speler 2, die op basis van regels speelt, analyseren. Dit stelt ons in staat om te beoordelen welke regels het meest worden toegepast en of de rule-based speler consequent beter presteert dan een speler die volledig op willekeurige zetten vertrouwt.
#
# Let op: dit is een voorlopig plan en staat nog niet vast!
#
# Daarnaast voorzien we in een extra main.py-bestand waarin we experimenteren met verbeterde of alternatieve regels. Op basis van de feedback en observaties uit de testfases passen we de regels aan, met als doel een effectiever systeem te ontwikkelen. Hiermee streven we ernaar dat het systeem, door de geïmplementeerde optimalisaties, in toekomstige tests vaker wint ten opzichte van een willekeurige tegenstander.

# %%
import main

main.play_game()
# Out:
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
#  0 1 2 3 4 5 6
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# X · · O · · ·
#  0 1 2 3 4 5 6
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · O · · ·
# X X · O · · ·
#  0 1 2 3 4 5 6
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · O · · ·
# · · · O · · ·
# X X X O · · ·
#  0 1 2 3 4 5 6
# ...
# Speler 2 wint!
# ...

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Opmerkingen na het testen van het systeem</strong> </div>
#
# **Feedback op huidige rule‑based agent**
#
# ---
#
# **Overmatige middelpreferrentie**
# Agent vult consequent eerst de exacte middelste kolom (kolom 3), ook wanneer dit geen tactisch voordeel biedt. Zodra kolom 3 vol is, schuift de voorkeur één kolom naar links, daarna de meest linker kolom — dit leidt tot voorspelbaar en ineffectief stapelen.
#
#
#
# **Ontbrekende diagonale en horizontale win‑strategieën**
# Agent detecteert en benut geen schuine (diagonale) of horizontale winstkansen. Zelfs als een directe diagonale vier‑op‑een‑rij beschikbaar is, kiest de agent niet voor die winnende zet.
#
#
# **Onvoldoende blokkeer‑logica**
# Agent blokkeert niet consistent tegenstander’s potentiële winlijnen; soms laat hij de gebruiker vier‑op‑een‑rij maken terwijl eigen verticale stapeling prioriteit krijgt.
#
#
#
# **Zelf‑winst boven preventie van tegenstander**
# Bij conflict tussen eigen winmogelijkheid en het blokkeren van een directe dreiging, kiest de agent voor eigen verticale stapeling — dit resulteert vaak in verlies.
#
#
#
# **Geen strategie voor dubbele dreigingen of open drie‑in‑een‑rij**
# Er is geen WERKENDE regel om dubbele win‑dreigingen te creëren of om open drie‑in‑een‑rij situaties te benutten.
#
#
# **Geen veiligheidsoverweging voor potentiële tegenwinst**
# Agent plaatst soms een zet die de tegenstander direct een winstmogelijkheid biedt in de volgende beurt.
#
#
#
# **Gebrek aan variatie in openingszet**
# Agent start altijd in het midden (of de kolom links zodra deze vol is), waardoor alle spellen identieke openingspatronen hebben.
#
#
# **Samenvatting**
# Het huidige rule‑based systeem hanteert één dominante strategie — het rule-based systeem ookal geven wij geen hoge prioriteit aan regel 6 (Voorkeur midden). En zet deze move eigenlijk 95% van de tijd. Stel je voor de tegenstander speelt dezelfde moves als ons rule based systeem zal je altijd dezelfde game krijgen
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <a name='5.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>Genereren van spellen</strong></h2>
# </div>

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Main Bestand Refresh</strong> </div>
# Voer dit bestand uit nadat je het main.py of main_verbeterd.py bestand hebt aangepast (soms) neemt hij de nieuwe aanpassingen anders niet mee bij het uitvoeren

# %%
import importlib
import main
importlib.reload(main)
# Out:
# <module 'main' from 'c:\\Users\\rogie\\OneDrive\\Bureaublad\\ADS-AI-Jaar 3\\Autonomous Systems\\Portfolio opdracht 1\\Autonomous-Systems\\main.py'>

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Uitvoeren van een singulair gegenereerd spel</strong> </div>
# Deze stap was voor mij vooral voor het bugfixen van de code, hier kan je zien of het rule based systeem wel de correcte keuzes aan het maken was, tijdens het testen van deze functie kreeg ik namelijk vaak dat de keuzes van het rule based systeem erg verschilde met de keuzes die hij maakte als ik tegen het systeem speelde

# %%
def display_single_game():
    env.reset(seed=42)
    print("=== Start Connect Four ===\n")
    render_board()

    agent_to_player = {"player_0": 1, "player_1": 2}
    moves_log = []
    winner = None

    for agent in env.agent_iter():
        obs, reward, termination, truncation, _ = env.last()
        if termination or truncation:
            if reward == 1:
                winner = agent_to_player[agent]
            elif reward == -1:
                winner = 3 - agent_to_player[agent]
            break

        board = convert_observation(obs["observation"])
        mask = obs["action_mask"]

        if agent == "player_0":
            valid = [i for i,v in enumerate(mask) if v]
            action, rule = random.choice(valid), "Random"
        else:
            action, rule = rule_based_action({"board": board, "action_mask": mask}, agent)

        moves_log.append((agent_to_player[agent], action, rule))
        env.step(action)
        render_board()

    print("\n=== Einde Spel ===")
    if winner:
        print(f"🎉 Speler {winner} wint! 🎉")
    else:
        print("🤝 Gelijkspel! 🤝")

    print("\nZet‑log:")
    for i, (player, move, rule) in enumerate(moves_log, start=1):
        print(f"{i:>2}. Speler {player} → kolom {move} ({rule})")

# Run it
display_single_game()
# Out:
# === Start Connect Four ===
# === Einde Spel ===
# 🎉 Speler 2 wint! 🎉
#
# Zet‑log:
#  1. Speler 1 → kolom 1 (Random)
#  2. Speler 2 → kolom 3 (6)
#  3. Speler 1 → kolom 2 (Random)
#  4. Speler 2 → kolom 3 (6)
#  5. Speler 1 → kolom 2 (Random)
#  6. Speler 2 → kolom 3 (6)
#  7. Speler 1 → kolom 4 (Random)
#  8. Speler 2 → kolom 3 (6)

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Het genereren van 1000 spellen</strong> </div>
# In dit stuk zullen we 1000 spellen gaan genereren om te kijken hoe robuust het rule based systeem is en welke rules het systeem het meest gebruikt

# %%
# Mapping Rule ID → leesbare naam
rule_names = {
    1: "Direct winnen",
    2: "Blokkeer tegenstander",
    3: "Creëer drie‑in‑een‑rij",
    4: "Dubbele dreiging",
    5: "Blokkeer drie‑in‑een‑rij",
    6: "Voorkeur midden",
    7: "Vermijd verlieszet",
    8: "Willekeurige zet"
}

def simulate_games(num_games=1000):
    records = []
    wins = {"player_0": 0, "player_1": 0, "draw": 0}

    for game in range(num_games):
        env.reset(seed=random.randrange(10**6))
        winner = None

        for agent in env.agent_iter():
            obs, reward, termination, trunc, _ = env.last()
            if termination or trunc:
                if reward == 1:
                    winner = agent
                elif reward == -1:
                    winner = "player_0" if agent=="player_1" else "player_1"
                break

            board = convert_observation(obs["observation"])
            mask = obs["action_mask"]

            if agent == "player_0":
                action, rule_id = rule_based_action({"board": board, "action_mask": mask}, agent)
            else:
                valid = [i for i,v in enumerate(mask) if v]
                action, rule_id = random.choice(valid), "Random"

            env.step(action)
            records.append({
                "game": game,
                "agent": agent,
                "rule": rule_id,
                "rule_name": rule_names.get(rule_id, "Random")
            })

        wins[winner or "draw"] += 1

    return pd.DataFrame(records), wins

# Run simulation
df, wins = simulate_games(1000)
print("Win stats:", wins)

# Plot rule‑usage voor alleen rule‑based agent (player_0)
usage = df[df["agent"]=="player_0"]["rule_name"].value_counts().sort_values()

plt.figure(figsize=(10,5))
usage.plot.bar()
plt.title("Regel‑gebruik Rule‑Based Agent (1.000 spellen)")
plt.xlabel("Regel")
plt.ylabel("Aantal keer toegepast")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Win stats: {'player_0': 925, 'player_1': 75, 'draw': 0}

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Toelichting</strong> </div>
# Hier zien we duidelijk dat het systeem te veel prioriteit geeft aan de regel 'voorkeur midden'. We begrijpen nog niet volledig waarom deze regel zo sterk wordt benadrukt, zeker omdat er geen specifieke instelling is geïmplementeerd om deze prioriteit af te dwingen. In het volgende hoofdstuk zullen we dit verder onderzoeken en verbeteren. Op deze manier kunnen we een interactiever en reactiever rule-based systeem ontwikkelen.

# %%
# Maak een Series van de win‑stats (excl. draw)
win_series = pd.Series({
    "Player 0 (Rule‑Based)": wins["player_0"],
    "Player 1 (Random Strategie)": wins["player_1"]
})

plt.figure(figsize=(6,4))
win_series.plot.bar()
plt.title("Aantal gewonnen spellen per speler (1.000 games)")
plt.xlabel("Speler")
plt.ylabel("Aantal overwinningen")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Uitkomsten van 25 spellen laten zien</strong> </div>

# %%
# Visualiseer laatste frames van de eerste 25 spellen
def simulate_first_n_games(n=25):
    frames = []
    for game in range(n):
        env.reset(seed=random.randrange(10**6))
        for agent in env.agent_iter():
            obs, reward, term, trunc, _ = env.last()
            if term or trunc:
                break
            board = convert_observation(obs["observation"])
            mask = obs["action_mask"]
            if agent == "player_0":
                action, _ = rule_based_action({"board": board, "action_mask": mask}, agent)
            else:
                valid = [i for i,v in enumerate(mask) if v]
                action, _ = random.choice(valid), "Random"
            env.step(action)
        frames.append(env.render())
    return frames

frames = simulate_first_n_games(25)

fig, axes = plt.subplots(5,5, figsize=(12,12))
fig.suptitle("Laatste frames van de eerste 25 spellen", fontsize=16)
for i, ax in enumerate(axes.flatten()):
    ax.imshow(frames[i])
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Opmerkingen na nog meer uitgebreide inspectie van het systeem</strong> </div>
# Dingen die we graag verbeterd willen zien in het rule-based systeem:
#
# **Localisatie van winstzetten:**
# Een manier implementeren zodat het systeem ook winstzetten kan herkennen die schuin worden gespeeld. Dit omvat zowel het zelf schuin winnen als het blokkeren van een schuine zet van de tegenstander.
#
# **Focus op counteren van de tegenstander:**
# Het systeem zou meer moeten richten op het tegenhouden van de tegenstander. Het moet in staat zijn om de winnende zet van de tegenstander te herkennen en deze prioriteit te geven boven eigen zetten.
#
# **Testen zonder de "voorkeur midden"-regel:**
# De huidige voorkeur voor het midden resulteerde er vaak in dat het systeem op dezelfde manier won, wat niet werkbaar is tegen een oprechte tegenstander. Het testen zonder deze regel is daarom gewenst.
#
# **Logischer zetkeuzes:**
# Het systeem moet zorgen voor meer logische zetten. Bijvoorbeeld: als een kolom niet langer mogelijkheden biedt om 4 op een rij te maken of als een zet niet logisch is ten opzichte van het bord, dan moet het systeem deze zet vermijden.

# %% [markdown]
# <a name='5.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>Verbeteren van de Regels </strong></h2>
# </div>

# %% [markdown]
# In dit stuk gaan we aan de hand van de feedback de regels proberen te verbeteren om een beter rule based_systeem te maken

# %%
import importlib
import main_verbeterd
importlib.reload(main_verbeterd)
# Out:
# <module 'main_verbeterd' from 'c:\\Users\\Peet\\Autonomous-Systems\\main_verbeterd.py'>

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Zelf testen van het verbeterde systeem</strong> </div>

# %%
main_verbeterd.play_game_improved()
# Out:
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
#  0 1 2 3 4 5 6
# [player_1] kiest kolom 0 (R6:Heuristic(score=0))
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# O · · X · · ·
#  0 1 2 3 4 5 6
# [player_1] kiest kolom 0 (R6:Heuristic(score=0))
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# · · · · · · ·
# O · · X · · ·
# O · · X · · ·
#  0 1 2 3 4 5 6
# [player_1] kiest kolom 0 (R6:Heuristic(score=0))
# · · · · · · ·
# · · · · · · ·
# O · · · · · ·
# X · · · · · ·
# O · · X · · ·
# O · · X · · ·
#  0 1 2 3 4 5 6
# Ongeldige zet — probeer opnieuw.
# [player_1] kiest kolom 0 (R6:Heuristic(score=0))
# O · · · · · ·
# X · · · · · ·
# O · · · · · ·
# X · · · · · ·
# O · · X · · ·
# O · · X · · ·
#  0 1 2 3 4 5 6
# Ongeldige zet — probeer opnieuw.
# Ongeldige zet — probeer opnieuw.
# Ongeldige zet — probeer opnieuw.
# Ongeldige zet — probeer opnieuw.
# Ongeldige zet — probeer opnieuw.
# ...

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Displayen van 1 game</strong> </div>

# %%
def display_single_game():
    """
    Speelt een enkel spel waarbij beide spelers via minimax (AI) een zet doen.
    Het bord wordt na elke zet gerenderd en aan het einde wordt het resultaat en een zet‑log weergegeven.
    """
    env.reset(seed=42)
    print("=== Start Connect Four (Verbeterde versie) ===\n")
    render_board()

    agent_to_player = {"player_0": 1, "player_1": 2}
    moves_log = []
    winner = None

    for agent in env.agent_iter():
        obs, reward, termination, trunc, _ = env.last()
        if termination or trunc:
            if reward == 1:
                winner = agent_to_player[agent]
            elif reward == -1:
                winner = 3 - agent_to_player[agent]
            break

        obs_dict = {
            "board": convert_observation(obs["observation"]),
            "action_mask": obs["action_mask"]
        }
        # Beide spelers gebruiken de minimax-AI.
        action, rule = ai_action_minimax(obs_dict, agent)
        moves_log.append((agent_to_player[agent], action, rule))
        env.step(action)
        render_board()

    print("\n=== Einde Spel ===")
    if winner:
        print(f"🎉 Speler {winner} wint! 🎉")
    else:
        print("🤝 Gelijkspel! 🤝")

    print("\nZet‑log:")
    for i, (player, move, rule) in enumerate(moves_log, start=1):
        print(f"{i:>2}. Speler {player} → kolom {move} ({rule})")

# Run it
display_single_game()
# Out:
# === Start Connect Four (Verbeterde versie) ===
# === Einde Spel ===
# 🎉 Speler 1 wint! 🎉
#
# Zet‑log:
#  1. Speler 1 → kolom 0 (Minimax)
#  2. Speler 2 → kolom 0 (Minimax)
#  3. Speler 1 → kolom 1 (Minimax)
#  4. Speler 2 → kolom 1 (Minimax)
#  5. Speler 1 → kolom 1 (Minimax)
#  6. Speler 2 → kolom 1 (Minimax)
#  7. Speler 1 → kolom 4 (Minimax)
#  8. Speler 2 → kolom 4 (Minimax)
#  9. Speler 1 → kolom 4 (Minimax)
# 10. Speler 2 → kolom 2 (Minimax)
# 11. Speler 1 → kolom 2 (Minimax)
# 12. Speler 2 → kolom 4 (Minimax)
# 13. Speler 1 → kolom 2 (Minimax)
# 14. Speler 2 → kolom 4 (Minimax)
# 15. Speler 1 → kolom 4 (Minimax)
# 16. Speler 2 → kolom 2 (Minimax)
# 17. Speler 1 → kolom 3 (Minimax)
# 18. Speler 2 → kolom 3 (Minimax)
# 19. Speler 1 → kolom 3 (Minimax)

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Simuleren van 1000 games</strong> </div>

# %%
import random
import pandas as pd

def simulate_games(num_games=1000):
    """
    Simuleer een aantal spellen en log per zet:
      - game-nummer
      - agent ("player_0" of "player_1")
      
    Aangenomen wordt dat:
      - player_0 de AI is (minimax).
      - player_1 een willekeurige zet kiest.
      
    Retourneert een DataFrame met de zet-logs en een dictionary met winststatistieken.
    """
    records = []
    wins = {"player_0": 0, "player_1": 0, "draw": 0}

    for game in range(num_games):
        # Reset de omgeving met een willekeurige seed
        env.reset(seed=random.randrange(10**6))
        winner = None

        for agent in env.agent_iter():
            obs, reward, termination, trunc, _ = env.last()
            if termination or trunc:
                if reward == 1:
                    winner = agent
                elif reward == -1:
                    winner = "player_0" if agent == "player_1" else "player_1"
                break

            board = convert_observation(obs["observation"])
            mask = obs["action_mask"]

            # Verkrijg de lijst met geldige zetten
            valid = [i for i, v in enumerate(mask) if v]
            
            # Kies de actie afhankelijk van de agent:
            if agent == "player_0":
                action, _ = ai_action_minimax({"board": board, "action_mask": mask}, agent)
            else:
                action = random.choice(valid)

            # Controleer of de gekozen actie geldig is
            if action not in valid:
                # print(f"[Game {game}] Ongeldige actie {action} door {agent}. Geldige zetten: {valid}. Kies willekeurig.")
                action = random.choice(valid)

            env.step(action)
            records.append({
                "game": game,
                "agent": agent,
            })

        wins[winner or "draw"] += 1

    return pd.DataFrame(records), wins

# Run de simulatie
df, wins = simulate_games(1000)
print("Win stats:", wins)
# print(df.head())
# Out:
# Win stats: {'player_0': 922, 'player_1': 78, 'draw': 0}
#    game     agent
# 0     0  player_0
# 1     0  player_1
# 2     0  player_0
# 3     0  player_1
# 4     0  player_0

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Win rates</strong> </div>

# %%
# Maak een Series van de win‑stats (excl. draw)
win_series = pd.Series({
    "Player 0 (Rule‑Based)": wins["player_0"],
    "Player 1 (Random Strategie)": wins["player_1"]
})

plt.figure(figsize=(6,4))
win_series.plot.bar()
plt.title("Aantal gewonnen spellen per speler (1.000 games)")
plt.xlabel("Speler")
plt.ylabel("Aantal overwinningen")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Visualiseren van 25 games in een grid</strong> </div>

# %%
def simulate_first_n_games(n=25):
    """
    Simuleer de eerste n spellen en verzamel het laatste gerenderde frame van elk spel.
    Voor speler 0 wordt de AI (minimax) gebruikt, voor speler 1 een willekeurige zet.
    Retourneert een lijst met frames.
    """
    frames = []
    for game in range(n):
        env.reset(seed=random.randrange(10**6))
        for agent in env.agent_iter():
            obs, reward, term, trunc, _ = env.last()
            if term or trunc:
                break
            board = convert_observation(obs["observation"])
            mask = obs["action_mask"]
            if agent == "player_0":
                # Gebruik de minimax-AI voor speler 0
                action, _ = ai_action_minimax({"board": board, "action_mask": mask}, agent)
            else:
                valid = [i for i, v in enumerate(mask) if v]
                action = random.choice(valid)
            env.step(action)
        frames.append(env.render())
    return frames

# Simuleer de eerste 25 spellen en verzamel de frames
frames = simulate_first_n_games(25)

# Visualiseer de frames in een 5x5 grid
fig, axes = plt.subplots(5, 5, figsize=(12, 12))
fig.suptitle("Laatste frames van de eerste 25 spellen", fontsize=16)
for i, ax in enumerate(axes.flatten()):
    ax.imshow(frames[i])
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#506375; color:white; padding: 10px;"> <strong>Hebben we de problemen opgelost?</strong> </div>
#
# In dit stuk zullen we dan beschrijven of we na de aanpassingen aan de regels het voor elkaar hebben kunnen krijgen om het systeem robuuster en beter te maken aan de hand van opmerkingen testen en feedback

# %% [markdown]
# <a name='4.2'></a>
# <h3>&sect;4.2: Documentatie en Retroduceerbaarheid</h3>

# %% [markdown]
# [Back to the top](#start)
# <a name='5.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H6: Validatie en Vergelijking</strong></h2>
# </div>

# %% [markdown]
# - [ ] Voer tests uit met realistische scenario’s.
# - [ ] Documenteer de prestaties van je systeem: hoe accuraat en efficiënt neemt het de juiste beslissingen?

# %% [markdown]
# <a name='5.1'></a>
# <h3>&sect;5.1: Testen en Evaluatie</h3>

# %% [markdown]
# - [ ] Vergelijk je rule-based systeem met de baseline aanpak.
# - [ ] Analyseer de voor- en nadelen van je systeem ten opzichte van de baseline.

# %% [markdown]
# <a name='5.2'></a>
# <h3>&sect;5.2: Vergelijking met Alternatieven</h3>

# %% [markdown]
# - [ ] Gebruik grafieken of tabellen om de prestaties en het gedrag van je systeem inzichtelijk te maken.

# %% [markdown]
# <a name='5.3'></a>
# <h3>&sect;5.3: Visualisatie</h3>

# %% [markdown]
# [Back to the top](#start)
# <a name='6.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H7: Rapport</strong></h2>
# </div>

# %% [markdown]
# - [ ] Beschrijving van het probleem en de motivatie voor een rule-based benadering.

# %% [markdown]
# <a name='6.1'></a>
# <h3>&sect;6.1: Probleemstelling</h3>

# %% [markdown]
# - [ ] Uitleg van de gekozen regels, ontwerpkeuzes en implementatiedetails.

# %% [markdown]
# <a name='6.2'></a>
# <h3>&sect;6.2: Methodologie</h3>

# %% [markdown]
# - [ ] Presentatie van de testresultaten, visualisaties en vergelijkende analyses.

# %% [markdown]
# <a name='6.3'></a>
# <h3>&sect;6.3: Resultaten</h3>

# %% [markdown]
# - [ ] Kritische evaluatie van de prestaties en beperkingen van je systeem.

# %% [markdown]
# <a name='6.4'></a>
# <h3>&sect;6.4: Reflectie</h3>

# %% [markdown]
# [Back to the top](#start)
# <a name='7.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H8: Literatuurlijst</strong></h2>
# </div>

# %% [markdown]
# [Back to the top](#start)
# <a name='8.0'></a>
#
# <div style="background-color:#216375; text-align:center; vertical-align:middle; padding:10px 0; margin-top:5px; margin-bottom:5px">
#         <h2 style="color:white"><strong>H9: Beoordelingscriteria</strong></h2>
# </div>

# %% [markdown]
# | Criteria                     | Level 4 (5p) | Level 3 (3p) | Level 2 (2p) | Level 1 (0p) |
# |------------------------------|-------------|-------------|-------------|-------------|
# | **Use-Case kiezen**          | Het probleem is goed gedefinieerd en er wordt uitgebreid uitgelegd, met goede argumenten, waarom een rule-based benadering het meest geschikt is, in tegenstelling tot andere benaderingen zoals ML. | Het probleem is goed gedefinieerd, maar de argumentatie is beperkt of vergelijkt de rule-based benadering niet met andere benaderingen. | Het probleem is niet goed gedefinieerd en het is onduidelijk waarom een rule-based benadering in dit geval geschikt is. | Het probleem is niet goed gedefinieerd en er wordt geen argumentatie gegeven. |
# | **Ontwerpen van de regelset** | De regelset is uitgebreid. Het dekt elk mogelijk scenario in de use-case. De regels zijn logisch en conflicteren niet met elkaar. Er is een uitgebreide uitleg gegeven voor de regelset en de code is goed gedocumenteerd. | De regelset is goed gedefinieerd, logisch en uitgebreid. De uitleg is echter onduidelijk en de documentatie is beperkt of onvolledig. | De regelset is gedeeltelijk geschikt voor het use-case scenario. Er zijn echter onlogische inconsistenties of conflicten tussen de regels. Of / en er zijn situaties die niet door de regelset worden gedekt, of waarbij de regelset onduidelijke of onbedoelde gevolgen heeft. | De regelset is (bijna) volledig ongeschikt voor het gebruiksscenario. |
# | **Implementatie**            | De Python-implementatie werkt volledig zoals verwacht. De agent volgt de regelset in elke situatie in de simulatie. De simulatie is 100% reproduceerbaar en toont elke keer de verwachte resultaten. | De Python-implementatie werkt voor het grootste gedeelte van de simulatie, maar faalt in bepaalde scenario's of de agent vertoont af en toe onverwacht gedrag, of de simulatie is niet 100% reproduceerbaar. | De Python-implementatie is rommelig en presteert niet zoals verwacht. De agent faalt vaak of vertoont voor het grootste deel onverwacht gedrag, of de simulatie is bijna nooit reproduceerbaar. | De Python-implementatie werkt nauwelijks of helemaal niet. |
# | **Validatie en vergelijking** | De simulatie wordt getest met realistische scenario's en de prestaties worden grondig geanalyseerd. De resultaten van deze analyse worden duidelijk gevisualiseerd. | Er zijn een behoorlijk aantal tests uitgevoerd, maar de testcases zouden uitgebreider kunnen zijn en de analyse van de resultaten zou diepgaander kunnen zijn. | Er is een zeer beperkt aantal testen uitgevoerd of de resultaten zijn niet op een bevredigend niveau geanalyseerd en gevisualiseerd. | Er is nauwelijks tot geen testing gedaan. |
# | **Rapporteren**              | Het rapport is helder en goed gestructureerd. De methodologie is goed uitgelegd. | Het rapport is bevredigend, maar het is niet goed gestructureerd en uitgelegd. | Het rapport is rommelig en er ontbreken belangrijke details. | Het rapport is onbevredigend, onjuist of afwezig. |
